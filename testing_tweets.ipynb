# %%
import pickle
import tweepy
item = pickle.load( open( "3m.pickle", "rb" ) )
p
print(item[-1])
# Out:
# Status(_json={'created_at': 'Wed Feb 24 19:51:59 +0000 2016', 'id': 702581760455020544, 'id_str': '702581760455020544', 'text': "@florsete Hi Katia -- We're sorry it took so long for the stethoscope to reach you. But it sounds like you have it now, correct? Thank you.", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'florsete', 'name': 'Katia', 'id': 16872315, 'id_str': '16872315', 'indices': [0, 9]}], 'urls': []}, 'source': '<a href="http://www.spredfast.com" rel="nofollow">Spredfast app</a>', 'in_reply_to_status_id': 702547023531266049, 'in_reply_to_status_id_str': '702547023531266049', 'in_reply_to_user_id': 16872315, 'in_reply_to_user_id_str': '16872315', 'in_reply_to_screen_name': 'florsete', 'user': {'id': 378197959, 'id_str': '378197959', 'name': '3M', 'screen_name': '3M', 'location': 'St Paul, MN', 'description': 'Here, we innovate with purpose & use #science every day to create real impact in every life around the world. #Li
# ...
